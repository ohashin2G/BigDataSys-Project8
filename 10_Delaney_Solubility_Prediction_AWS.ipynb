# %% [markdown]
# <h1>Predicting Solubility Using AMPL</h1>
#
# The ATOM Modeling PipeLine (AMPL; https://github.com/ATOMScience-org/AMPL) is an open-source, modular, extensible software pipeline for building and sharing models to advance in silico drug discovery.

# %% [markdown]
# ## Notebook execution time: ~ 3 minutes

# %%
# !date
# Out:
# Mon Feb 26 23:26:46 UTC 2024

# %% [markdown]
# # Goal: Predict solubility using the ATOM Modeling Pipeline (AMPL) on the public dataset
#
# In this notebook, we describe the following steps using AMPL:
#
# 1.   Read a public dataset containing chemical structures and some properties
# 1.   Curate the dataset
# 2.   Fit a simple model
# 3.   Predict solubility for withheld compounds
#
#
# ## Set up
# We first import the AMPL modules for use in this notebook.
#
# The relevant AMPL modules for this example are listed below:
#
# |module|Description|
# |-|-|
# |`atomsci.ddm.pipeline.model_pipeline`|The model pipeline module is used to fit models and load models for prediction.|
# |`atomsci.ddm.pipeline.parameter_parser`|The parameter parser reads through pipeline options for the model pipeline.|
# |`atomsci.ddm.utils.curate_data`|The curate data module is used for data loading and pre-processing.|
# |`atomsci.ddm.utils.struct_utils`|The structure utilities module is used to process loaded structures.|
# |`atomsci.ddm.pipeline.perf_plots`|Perf plots contains a variety of plotting functions.|

# %% [markdown]
# ## Install AMPL

# %%
! pip install rdkit-pypi
! pip install deepchem

import deepchem
# print(deepchem.__version__)
! pip install umap
! pip install -U --ignore-installed numba
! pip install umap-learn
! pip install molvs
! pip install bravado
# Out:
# Collecting rdkit-pypi
#   Using cached rdkit_pypi-2022.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.9 kB)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from rdkit-pypi) (1.26.3)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (from rdkit-pypi) (9.5.0)
# Using cached rdkit_pypi-2022.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29.4 MB)
# Installing collected packages: rdkit-pypi
# Successfully installed rdkit-pypi-2022.9.5
# Collecting deepchem
#   Using cached deepchem-2.7.1-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from deepchem) (1.3.2)
# Requirement already satisfied: numpy>=1.21 in /opt/conda/lib/python3.10/site-packages (from deepchem) (1.26.3)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from deepchem) (2.1.4)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from deepchem) (1.3.2)
# Collecting scipy<1.9 (from deepchem)
#   Using cached scipy-1.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.2 kB)
# Collecting rdkit (from deepchem)
#   Using cached rdkit-2023.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.9 kB)
# Collecting numpy>=1.21 (from deepchem)
#   Using cached numpy-1.24.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->deepchem) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->deepchem) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas->deepchem) (2023.4)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (from rdkit->deepchem) (9.5.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->deepchem) (3.2.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->deepchem) (1.16.0)
# Using cached deepchem-2.7.1-py3-none-any.whl (693 kB)
# Using cached scipy-1.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (42.2 MB)
# Using cached numpy-1.24.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
# Using cached rdkit-2023.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.4 MB)
# Installing collected packages: numpy, scipy, rdkit, deepchem
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.3
#     Uninstalling numpy-1.26.3:
#       Successfully uninstalled numpy-1.26.3
#   Attempting uninstall: scipy
#     Found existing installation: SciPy 1.11.4
#     Uninstalling SciPy-1.11.4:
#       Successfully uninstalled SciPy-1.11.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# hdijupyterutils 0.21.0 requires pandas<2.0.0,>=0.17.1, but you have pandas 2.1.4 which is incompatible.
# jax 0.4.20 requires scipy>=1.9, but you have scipy 1.8.1 which is incompatible.
# pandas-stubs 2.1.4.231227 requires numpy>=1.26.0; python_version < "3.13", but you have numpy 1.24.4 which is incompatible.
# sagemaker 2.198.1 requires boto3<2.0,>=1.29.6, but you have boto3 1.28.64 which is incompatible.
# sparkmagic 0.21.0 requires pandas<2.0.0,>=0.17.1, but you have pandas 2.1.4 which is incompatible.
# Successfully installed deepchem-2.7.1 numpy-1.24.4 rdkit-2023.9.5 scipy-1.8.1
# 2024-02-26 23:27:23.799605: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# wandb: WARNING W&B installed but not logged in.  Run `wandb login` or set the WANDB_API_KEY env variable.
# wandb: WARNING W&B installed but not logged in.  Run `wandb login` or set the WANDB_API_KEY env variable.
# Skipped loading modules with pytorch-geometric dependency, missing a dependency. No module named 'torch_geometric'
# Skipped loading modules with pytorch-geometric dependency, missing a dependency. cannot import name 'DMPNN' from 'deepchem.models.torch_models' (/opt/conda/lib/python3.10/site-packages/deepchem/models/torch_models/__init__.py)
# Skipped loading some Jax models, missing a dependency. No module named 'haiku'
# Collecting umap
#   Using cached umap-0.1.1-py3-none-any.whl
# Installing collected packages: umap
# Successfully installed umap-0.1.1
# Collecting numba
#   Using cached numba-0.59.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.7 kB)
# Collecting llvmlite<0.43,>=0.42.0dev0 (from numba)
#   Using cached llvmlite-0.42.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.8 kB)
# Collecting numpy<1.27,>=1.22 (from numba)
#   Using cached numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Using cached numba-0.59.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.7 MB)
# Using cached llvmlite-0.42.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (43.8 MB)
# Using cached numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
# Installing collected packages: numpy, llvmlite, numba
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# hdijupyterutils 0.21.0 requires pandas<2.0.0,>=0.17.1, but you have pandas 2.1.4 which is incompatible.
# jax 0.4.20 requires scipy>=1.9, but you have scipy 1.8.1 which is incompatible.
# sagemaker 2.198.1 requires boto3<2.0,>=1.29.6, but you have boto3 1.28.64 which is incompatible.
# scipy 1.8.1 requires numpy<1.25.0,>=1.17.3, but you have numpy 1.26.4 which is incompatible.
# sparkmagic 0.21.0 requires pandas<2.0.0,>=0.17.1, but you have pandas 2.1.4 which is incompatible.
# Successfully installed llvmlite-0.41.1 numba-0.58.1 numpy-1.24.4
# Collecting umap-learn
#   Using cached umap_learn-0.5.5-py3-none-any.whl
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from umap-learn) (1.24.4)
# Requirement already satisfied: scipy>=1.3.1 in /opt/conda/lib/python3.10/site-packages (from umap-learn) (1.8.1)
# Requirement already satisfied: scikit-learn>=0.22 in /opt/conda/lib/python3.10/site-packages (from umap-learn) (1.3.2)
# Requirement already satisfied: numba>=0.51.2 in /opt/conda/lib/python3.10/site-packages (from umap-learn) (0.58.1)
# Collecting pynndescent>=0.5 (from umap-learn)
#   Using cached pynndescent-0.5.11-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from umap-learn) (4.66.1)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /opt/conda/lib/python3.10/site-packages (from numba>=0.51.2->umap-learn) (0.41.1)
# Requirement already satisfied: joblib>=0.11 in /opt/conda/lib/python3.10/site-packages (from pynndescent>=0.5->umap-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.22->umap-learn) (3.2.0)
# Using cached pynndescent-0.5.11-py3-none-any.whl (55 kB)
# Installing collected packages: pynndescent, umap-learn
# Successfully installed pynndescent-0.5.11 umap-learn-0.5.5
# Collecting molvs
#   Using cached MolVS-0.1.1-py3-none-any.whl
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from molvs) (1.16.0)
# Installing collected packages: molvs
# Successfully installed molvs-0.1.1
# Collecting bravado
#   Using cached bravado-11.0.3-py2.py3-none-any.whl.metadata (5.9 kB)
# Collecting bravado-core>=5.16.1 (from bravado)
#   Using cached bravado_core-6.1.1-py2.py3-none-any.whl
# Requirement already satisfied: msgpack in /opt/conda/lib/python3.10/site-packages (from bravado) (1.0.7)
# Requirement already satisfied: python-dateutil in /opt/conda/lib/python3.10/site-packages (from bravado) (2.8.2)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from bravado) (6.0.1)
# Requirement already satisfied: requests>=2.17 in /opt/conda/lib/python3.10/site-packages (from bravado) (2.31.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from bravado) (1.16.0)
# Collecting simplejson (from bravado)
#   Using cached simplejson-3.19.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.1 kB)
# Collecting monotonic (from bravado)
#   Using cached monotonic-1.6-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from bravado) (4.5.0)
# Collecting jsonref (from bravado-core>=5.16.1->bravado)
#   Using cached jsonref-1.1.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: jsonschema>=2.5.1 in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=2.5.1->bravado-core>=5.16.1->bravado) (4.17.3)
# Collecting swagger-spec-validator>=2.0.1 (from bravado-core>=5.16.1->bravado)
#   Using cached swagger_spec_validator-3.0.3-py2.py3-none-any.whl.metadata (709 bytes)
# Requirement already satisfied: pytz in /opt/conda/lib/python3.10/site-packages (from bravado-core>=5.16.1->bravado) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.17->bravado) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.17->bravado) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.17->bravado) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.17->bravado) (2023.11.17)
# Requirement already satisfied: attrs>=17.4.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.5.1->jsonschema[format-nongpl]>=2.5.1->bravado-core>=5.16.1->bravado) (23.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.5.1->jsonschema[format-nongpl]>=2.5.1->bravado-core>=5.16.1->bravado) (0.20.0)
# Requirement already satisfied: fqdn in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=2.5.1->bravado-core>=5.16.1->bravado) (1.5.1)
# Requirement already satisfied: isoduration in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=2.5.1->bravado-core>=5.16.1->bravado) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=2.5.1->bravado-core>=5.16.1->bravado) (2.4)
# Requirement already satisfied: rfc3339-validator in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=2.5.1->bravado-core>=5.16.1->bravado) (0.1.4)
# Requirement already satisfied: rfc3986-validator>0.1.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=2.5.1->bravado-core>=5.16.1->bravado) (0.1.1)
# Requirement already satisfied: uri-template in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=2.5.1->bravado-core>=5.16.1->bravado) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=2.5.1->bravado-core>=5.16.1->bravado) (1.13)
# Requirement already satisfied: arrow>=0.15.0 in /opt/conda/lib/python3.10/site-packages (from isoduration->jsonschema[format-nongpl]>=2.5.1->bravado-core>=5.16.1->bravado) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /opt/conda/lib/python3.10/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=2.5.1->bravado-core>=5.16.1->bravado) (2.8.19.20240106)
# Using cached bravado-11.0.3-py2.py3-none-any.whl (38 kB)
# Using cached monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Using cached simplejson-3.19.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (137 kB)
# Using cached swagger_spec_validator-3.0.3-py2.py3-none-any.whl (27 kB)
# Using cached jsonref-1.1.0-py3-none-any.whl (9.4 kB)
# Installing collected packages: monotonic, simplejson, jsonref, swagger-spec-validator, bravado-core, bravado
# Successfully installed bravado-11.0.3 bravado-core-6.1.1 jsonref-1.1.0 monotonic-1.6 simplejson-3.19.2 swagger-spec-validator-3.0.3

# %%
import deepchem as dc

# get the Install AMPL_GPU_test.sh
! wget 'https://raw.githubusercontent.com/ATOMScience-org/AMPL/master/atomsci/ddm/examples/tutorials/config/install_AMPL_GPU_test.sh' >& /dev/null

# run the script to install AMPL
! chmod u+x install_AMPL_GPU_test.sh
! ./install_AMPL_GPU_test.sh
# Out:
# mkdir: cannot create directory ‘github’: File exists
# fatal: destination path 'AMPL' already exists and is not an empty directory.
# Already on 'master'
# Your branch is up to date with 'origin/master'.
# /opt/conda/lib/python3.10/site-packages/setuptools/dist.py:674: SetuptoolsDeprecationWarning: The namespace_packages parameter is deprecated.
# !!
#
#         ********************************************************************************
#         Please replace its usage with implicit namespaces (PEP 420).
#
#         See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages for details.
#         ********************************************************************************
#
# !!
#   ep.load()(self, ep.name, value)
# running build
# running build_py
# copying atomsci/__init__.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci
# copying atomsci/ddm/__init__.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm
# copying atomsci/ddm/pipeline/GeneticAlgorithm.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/MultitaskScaffoldSplit.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/__init__.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/ave_splitter.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/chem_diversity.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/compare_models.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/dist_metrics.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/diversity_plots.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/feature_importance.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/featurization.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/hyper_perf_plots.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/model_datasets.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/model_pipeline.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/model_tracker.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/model_wrapper.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/parameter_parser.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/perf_data.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/perf_plots.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/predict_from_model.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/splitting.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/temporal_splitter.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/transformations.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/utils/__init__.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/checksum_utils.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/compare_split_csv.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/compare_splits_plots.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/curate_data.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/data_curation_functions.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/datastore_functions.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/file_utils.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/genTestset.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/hyperparam_search_wrapper.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/llnl_utils.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/many_to_one.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/model_file_reader.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/model_retrain.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/model_version_utils.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/open-docs.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/patch_model_dataset_key.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/process_slurm.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/pubchem_utils.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/rdkit_easy.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/split_response_dist_plots.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/struct_utils.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/test_utils.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# running egg_info
# writing /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/atomsci_ampl.egg-info/PKG-INFO
# writing dependency_links to /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/atomsci_ampl.egg-info/dependency_links.txt
# writing namespace_packages to /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/atomsci_ampl.egg-info/namespace_packages.txt
# writing top-level names to /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/atomsci_ampl.egg-info/top_level.txt
# reading manifest file '/home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/atomsci_ampl.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching 'atomsci/*/*.yaml'
# adding license file 'LICENSE'
# adding license file 'NOTICE'
# writing manifest file '/home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/atomsci_ampl.egg-info/SOURCES.txt'
# /opt/conda/lib/python3.10/site-packages/setuptools/command/build_py.py:207: _Warning: Package 'atomsci.ddm.data' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'atomsci.ddm.data' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'atomsci.ddm.data' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'atomsci.ddm.data' to be distributed and are
#         already explicitly excluding 'atomsci.ddm.data' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# copying atomsci/ddm/data/descriptor_sets_sources_by_descr_type.csv -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/data
# copying atomsci/ddm/utils/open-docs.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# running bdist_wheel
# /opt/conda/lib/python3.10/site-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# installing to /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel
# running install
# running install_lib
# Skipping installation of /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/__init__.py (namespace package)
# copying atomsci/ddm/__init__.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm
# copying atomsci/ddm/pipeline/GeneticAlgorithm.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/MultitaskScaffoldSplit.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/__init__.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/ave_splitter.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/chem_diversity.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/compare_models.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/dist_metrics.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/diversity_plots.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/feature_importance.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/featurization.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/hyper_perf_plots.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/model_datasets.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/model_pipeline.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/model_tracker.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/model_wrapper.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/parameter_parser.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/perf_data.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/perf_plots.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/predict_from_model.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/splitting.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/temporal_splitter.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/transformations.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/utils/struct_utils.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/test_utils.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/open-docs.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/__init__.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/checksum_utils.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/compare_split_csv.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/compare_splits_plots.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/curate_data.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/data_curation_functions.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/datastore_functions.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/file_utils.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/genTestset.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/hyperparam_search_wrapper.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/llnl_utils.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/many_to_one.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/model_file_reader.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/model_retrain.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/model_version_utils.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/patch_model_dataset_key.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/process_slurm.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/pubchem_utils.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/rdkit_easy.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/split_response_dist_plots.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/data/descriptor_sets_sources_by_descr_type.csv -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/data
# running install_egg_info
# Copying /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/atomsci_ampl.egg-info to /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci_ampl-1.6.0-py3.10.egg-info
# Installing /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci_ampl-1.6.0-py3.10-nspkg.pth
# running install_scripts
# creating /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci_ampl-1.6.0.dist-info/WHEEL
# creating '/home/sagemaker-user/BigDataSys-Project8/github/AMPL.dist/atomsci_ampl-1.6.0-py3-none-any.whl' and adding '/home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel' to it
# adding 'atomsci_ampl-1.6.0-py3.10-nspkg.pth'
# adding 'atomsci/ddm/__init__.py'
# adding 'atomsci/ddm/data/descriptor_sets_sources_by_descr_type.csv'
# adding 'atomsci/ddm/pipeline/GeneticAlgorithm.py'
# adding 'atomsci/ddm/pipeline/MultitaskScaffoldSplit.py'
# adding 'atomsci/ddm/pipeline/__init__.py'
# adding 'atomsci/ddm/pipeline/ave_splitter.py'
# adding 'atomsci/ddm/pipeline/chem_diversity.py'
# adding 'atomsci/ddm/pipeline/compare_models.py'
# adding 'atomsci/ddm/pipeline/dist_metrics.py'
# adding 'atomsci/ddm/pipeline/diversity_plots.py'
# adding 'atomsci/ddm/pipeline/feature_importance.py'
# adding 'atomsci/ddm/pipeline/featurization.py'
# adding 'atomsci/ddm/pipeline/hyper_perf_plots.py'
# adding 'atomsci/ddm/pipeline/model_datasets.py'
# adding 'atomsci/ddm/pipeline/model_pipeline.py'
# adding 'atomsci/ddm/pipeline/model_tracker.py'
# adding 'atomsci/ddm/pipeline/model_wrapper.py'
# adding 'atomsci/ddm/pipeline/parameter_parser.py'
# adding 'atomsci/ddm/pipeline/perf_data.py'
# adding 'atomsci/ddm/pipeline/perf_plots.py'
# adding 'atomsci/ddm/pipeline/predict_from_model.py'
# adding 'atomsci/ddm/pipeline/splitting.py'
# adding 'atomsci/ddm/pipeline/temporal_splitter.py'
# adding 'atomsci/ddm/pipeline/transformations.py'
# adding 'atomsci/ddm/utils/__init__.py'
# adding 'atomsci/ddm/utils/checksum_utils.py'
# adding 'atomsci/ddm/utils/compare_split_csv.py'
# adding 'atomsci/ddm/utils/compare_splits_plots.py'
# adding 'atomsci/ddm/utils/curate_data.py'
# adding 'atomsci/ddm/utils/data_curation_functions.py'
# adding 'atomsci/ddm/utils/datastore_functions.py'
# adding 'atomsci/ddm/utils/file_utils.py'
# adding 'atomsci/ddm/utils/genTestset.py'
# adding 'atomsci/ddm/utils/hyperparam_search_wrapper.py'
# adding 'atomsci/ddm/utils/llnl_utils.py'
# adding 'atomsci/ddm/utils/many_to_one.py'
# adding 'atomsci/ddm/utils/model_file_reader.py'
# adding 'atomsci/ddm/utils/model_retrain.py'
# adding 'atomsci/ddm/utils/model_version_utils.py'
# adding 'atomsci/ddm/utils/open-docs.py'
# adding 'atomsci/ddm/utils/patch_model_dataset_key.py'
# adding 'atomsci/ddm/utils/process_slurm.py'
# adding 'atomsci/ddm/utils/pubchem_utils.py'
# adding 'atomsci/ddm/utils/rdkit_easy.py'
# adding 'atomsci/ddm/utils/split_response_dist_plots.py'
# adding 'atomsci/ddm/utils/struct_utils.py'
# adding 'atomsci/ddm/utils/test_utils.py'
# adding 'atomsci_ampl-1.6.0.dist-info/LICENSE'
# adding 'atomsci_ampl-1.6.0.dist-info/METADATA'
# adding 'atomsci_ampl-1.6.0.dist-info/NOTICE'
# adding 'atomsci_ampl-1.6.0.dist-info/WHEEL'
# adding 'atomsci_ampl-1.6.0.dist-info/namespace_packages.txt'
# adding 'atomsci_ampl-1.6.0.dist-info/top_level.txt'
# adding 'atomsci_ampl-1.6.0.dist-info/RECORD'
# removing /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel
# DIR: /home/sagemaker-user/BigDataSys-Project8/github/AMPL
# Using pip 23.3.2 from /opt/conda/lib/python3.10/site-packages/pip (python 3.10)
# Looking in links: /home/sagemaker-user/BigDataSys-Project8/github/AMPL.dist
# Processing /home/sagemaker-user/BigDataSys-Project8/github/AMPL.dist/atomsci_ampl-1.6.0-py3-none-any.whl
# Installing collected packages: atomsci_ampl
# Successfully installed atomsci_ampl-1.6.0

# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /opt/conda/lib/python3.10/site-packages (from seaborn) (1.24.4)
# Requirement already satisfied: pandas>=1.2 in /opt/conda/lib/python3.10/site-packages (from seaborn) (2.1.4)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /opt/conda/lib/python3.10/site-packages (from seaborn) (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.2)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2023.4)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# We temporarily disable warnings for demonstration.
# FutureWarnings and DeprecationWarnings are present from some of the AMPL
# dependency modules.
import warnings
warnings.filterwarnings('ignore')

import json
import numpy as np
import pandas as pd
import os
import requests
import sys

import atomsci.ddm.pipeline.model_pipeline as mp
import atomsci.ddm.pipeline.parameter_parser as parse
import atomsci.ddm.utils.curate_data as curate_data
import atomsci.ddm.utils.struct_utils as struct_utils
from atomsci.ddm.pipeline import perf_plots as pp

# %%
import os

# Specify the path to the directory
path_to_directory = '/home/sagemaker-user/BigDataSys-Project8'

# Change the current working directory
os.chdir(path_to_directory)

# Now import the atomsci.ddm module
import atomsci.ddm.pipeline.model_pipeline as mp

# %%
# Import DeepChem
import deepchem as dc

# Use these commands in a cell of your Jupyter notebook or in your shell

# Download the installation script for AMPL
# !wget 'https://raw.githubusercontent.com/ATOMScience-org/AMPL/master/atomsci/ddm/examples/tutorials/config/install_AMPL_GPU_test.sh'

# Make the script executable
# !chmod u+x install_AMPL_GPU_test.sh

# Execute the script
# !./install_AMPL_GPU_test.sh
# Out:
# --2024-02-26 23:29:42--  https://raw.githubusercontent.com/ATOMScience-org/AMPL/master/atomsci/ddm/examples/tutorials/config/install_AMPL_GPU_test.sh
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# ERROR: cannot verify raw.githubusercontent.com's certificate, issued by ‘CN=DigiCert TLS RSA SHA256 2020 CA1,O=DigiCert Inc,C=US’:
#   Unable to locally verify the issuer's authority.
# To connect to raw.githubusercontent.com insecurely, use `--no-check-certificate'.
# mkdir: cannot create directory ‘github’: File exists
# fatal: destination path 'AMPL' already exists and is not an empty directory.
# Already on 'master'
# Your branch is up to date with 'origin/master'.
# /opt/conda/lib/python3.10/site-packages/setuptools/dist.py:674: SetuptoolsDeprecationWarning: The namespace_packages parameter is deprecated.
# !!
#
#         ********************************************************************************
#         Please replace its usage with implicit namespaces (PEP 420).
#
#         See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages for details.
#         ********************************************************************************
#
# !!
#   ep.load()(self, ep.name, value)
# running build
# running build_py
# copying atomsci/__init__.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci
# copying atomsci/ddm/__init__.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm
# copying atomsci/ddm/pipeline/GeneticAlgorithm.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/MultitaskScaffoldSplit.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/__init__.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/ave_splitter.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/chem_diversity.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/compare_models.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/dist_metrics.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/diversity_plots.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/feature_importance.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/featurization.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/hyper_perf_plots.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/model_datasets.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/model_pipeline.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/model_tracker.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/model_wrapper.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/parameter_parser.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/perf_data.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/perf_plots.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/predict_from_model.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/splitting.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/temporal_splitter.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/transformations.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/utils/__init__.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/checksum_utils.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/compare_split_csv.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/compare_splits_plots.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/curate_data.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/data_curation_functions.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/datastore_functions.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/file_utils.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/genTestset.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/hyperparam_search_wrapper.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/llnl_utils.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/many_to_one.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/model_file_reader.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/model_retrain.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/model_version_utils.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/open-docs.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/patch_model_dataset_key.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/process_slurm.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/pubchem_utils.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/rdkit_easy.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/split_response_dist_plots.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/struct_utils.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/test_utils.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# running egg_info
# writing /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/atomsci_ampl.egg-info/PKG-INFO
# writing dependency_links to /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/atomsci_ampl.egg-info/dependency_links.txt
# writing namespace_packages to /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/atomsci_ampl.egg-info/namespace_packages.txt
# writing top-level names to /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/atomsci_ampl.egg-info/top_level.txt
# reading manifest file '/home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/atomsci_ampl.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching 'atomsci/*/*.yaml'
# adding license file 'LICENSE'
# adding license file 'NOTICE'
# writing manifest file '/home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/atomsci_ampl.egg-info/SOURCES.txt'
# /opt/conda/lib/python3.10/site-packages/setuptools/command/build_py.py:207: _Warning: Package 'atomsci.ddm.data' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'atomsci.ddm.data' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'atomsci.ddm.data' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'atomsci.ddm.data' to be distributed and are
#         already explicitly excluding 'atomsci.ddm.data' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# copying atomsci/ddm/data/descriptor_sets_sources_by_descr_type.csv -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/data
# copying atomsci/ddm/utils/open-docs.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# running bdist_wheel
# /opt/conda/lib/python3.10/site-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# installing to /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel
# running install
# running install_lib
# Skipping installation of /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/__init__.py (namespace package)
# copying atomsci/ddm/__init__.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm
# copying atomsci/ddm/pipeline/chem_diversity.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/compare_models.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/dist_metrics.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/diversity_plots.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/feature_importance.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/featurization.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/hyper_perf_plots.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/model_datasets.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/model_pipeline.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/model_tracker.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/model_wrapper.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/parameter_parser.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/perf_plots.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/predict_from_model.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/splitting.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/temporal_splitter.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/transformations.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/GeneticAlgorithm.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/MultitaskScaffoldSplit.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/__init__.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/ave_splitter.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/perf_data.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/utils/__init__.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/checksum_utils.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/compare_split_csv.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/compare_splits_plots.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/curate_data.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/data_curation_functions.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/datastore_functions.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/file_utils.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/genTestset.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/hyperparam_search_wrapper.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/llnl_utils.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/many_to_one.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/model_file_reader.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/model_retrain.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/model_version_utils.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/patch_model_dataset_key.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/process_slurm.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/pubchem_utils.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/rdkit_easy.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/split_response_dist_plots.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/struct_utils.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/test_utils.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/open-docs.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/data/descriptor_sets_sources_by_descr_type.csv -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/data
# running install_egg_info
# Copying /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/atomsci_ampl.egg-info to /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci_ampl-1.6.0-py3.10.egg-info
# Installing /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci_ampl-1.6.0-py3.10-nspkg.pth
# running install_scripts
# creating /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci_ampl-1.6.0.dist-info/WHEEL
# creating '/home/sagemaker-user/BigDataSys-Project8/github/AMPL.dist/atomsci_ampl-1.6.0-py3-none-any.whl' and adding '/home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel' to it
# adding 'atomsci_ampl-1.6.0-py3.10-nspkg.pth'
# adding 'atomsci/ddm/__init__.py'
# adding 'atomsci/ddm/data/descriptor_sets_sources_by_descr_type.csv'
# adding 'atomsci/ddm/pipeline/GeneticAlgorithm.py'
# adding 'atomsci/ddm/pipeline/MultitaskScaffoldSplit.py'
# adding 'atomsci/ddm/pipeline/__init__.py'
# adding 'atomsci/ddm/pipeline/ave_splitter.py'
# adding 'atomsci/ddm/pipeline/chem_diversity.py'
# adding 'atomsci/ddm/pipeline/compare_models.py'
# adding 'atomsci/ddm/pipeline/dist_metrics.py'
# adding 'atomsci/ddm/pipeline/diversity_plots.py'
# adding 'atomsci/ddm/pipeline/feature_importance.py'
# adding 'atomsci/ddm/pipeline/featurization.py'
# adding 'atomsci/ddm/pipeline/hyper_perf_plots.py'
# adding 'atomsci/ddm/pipeline/model_datasets.py'
# adding 'atomsci/ddm/pipeline/model_pipeline.py'
# adding 'atomsci/ddm/pipeline/model_tracker.py'
# adding 'atomsci/ddm/pipeline/model_wrapper.py'
# adding 'atomsci/ddm/pipeline/parameter_parser.py'
# adding 'atomsci/ddm/pipeline/perf_data.py'
# adding 'atomsci/ddm/pipeline/perf_plots.py'
# adding 'atomsci/ddm/pipeline/predict_from_model.py'
# adding 'atomsci/ddm/pipeline/splitting.py'
# adding 'atomsci/ddm/pipeline/temporal_splitter.py'
# adding 'atomsci/ddm/pipeline/transformations.py'
# adding 'atomsci/ddm/utils/__init__.py'
# adding 'atomsci/ddm/utils/checksum_utils.py'
# adding 'atomsci/ddm/utils/compare_split_csv.py'
# adding 'atomsci/ddm/utils/compare_splits_plots.py'
# adding 'atomsci/ddm/utils/curate_data.py'
# adding 'atomsci/ddm/utils/data_curation_functions.py'
# adding 'atomsci/ddm/utils/datastore_functions.py'
# adding 'atomsci/ddm/utils/file_utils.py'
# adding 'atomsci/ddm/utils/genTestset.py'
# adding 'atomsci/ddm/utils/hyperparam_search_wrapper.py'
# adding 'atomsci/ddm/utils/llnl_utils.py'
# adding 'atomsci/ddm/utils/many_to_one.py'
# adding 'atomsci/ddm/utils/model_file_reader.py'
# adding 'atomsci/ddm/utils/model_retrain.py'
# adding 'atomsci/ddm/utils/model_version_utils.py'
# adding 'atomsci/ddm/utils/open-docs.py'
# adding 'atomsci/ddm/utils/patch_model_dataset_key.py'
# adding 'atomsci/ddm/utils/process_slurm.py'
# adding 'atomsci/ddm/utils/pubchem_utils.py'
# adding 'atomsci/ddm/utils/rdkit_easy.py'
# adding 'atomsci/ddm/utils/split_response_dist_plots.py'
# adding 'atomsci/ddm/utils/struct_utils.py'
# adding 'atomsci/ddm/utils/test_utils.py'
# adding 'atomsci_ampl-1.6.0.dist-info/LICENSE'
# adding 'atomsci_ampl-1.6.0.dist-info/METADATA'
# adding 'atomsci_ampl-1.6.0.dist-info/NOTICE'
# adding 'atomsci_ampl-1.6.0.dist-info/WHEEL'
# adding 'atomsci_ampl-1.6.0.dist-info/namespace_packages.txt'
# adding 'atomsci_ampl-1.6.0.dist-info/top_level.txt'
# adding 'atomsci_ampl-1.6.0.dist-info/RECORD'
# removing /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel
# DIR: /home/sagemaker-user/BigDataSys-Project8/github/AMPL
# Using pip 23.3.2 from /opt/conda/lib/python3.10/site-packages/pip (python 3.10)
# Looking in links: /home/sagemaker-user/BigDataSys-Project8/github/AMPL.dist
# Processing /home/sagemaker-user/BigDataSys-Project8/github/AMPL.dist/atomsci_ampl-1.6.0-py3-none-any.whl
# Installing collected packages: atomsci_ampl
# Successfully installed atomsci_ampl-1.6.0

# %%
# !wget --no-check-certificate 'https://raw.githubusercontent.com/ATOMScience-org/AMPL/master/atomsci/ddm/examples/tutorials/config/install_AMPL_GPU_test.sh'

# Make the script executable (only if the download was successful)
# !chmod u+x install_AMPL_GPU_test.sh

# Execute the script (only if the file exists)
# !./install_AMPL_GPU_test.sh
# Out:
# --2024-02-26 23:29:45--  https://raw.githubusercontent.com/ATOMScience-org/AMPL/master/atomsci/ddm/examples/tutorials/config/install_AMPL_GPU_test.sh
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# WARNING: cannot verify raw.githubusercontent.com's certificate, issued by ‘CN=DigiCert TLS RSA SHA256 2020 CA1,O=DigiCert Inc,C=US’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: 179 [text/plain]
# Saving to: ‘install_AMPL_GPU_test.sh.1’
#
# install_AMPL_GPU_te 100%[===================>]     179  --.-KB/s    in 0s
#
# 2024-02-26 23:29:45 (10.8 MB/s) - ‘install_AMPL_GPU_test.sh.1’ saved [179/179]
#
# mkdir: cannot create directory ‘github’: File exists
# fatal: destination path 'AMPL' already exists and is not an empty directory.
# Already on 'master'
# Your branch is up to date with 'origin/master'.
# /opt/conda/lib/python3.10/site-packages/setuptools/dist.py:674: SetuptoolsDeprecationWarning: The namespace_packages parameter is deprecated.
# !!
#
#         ********************************************************************************
#         Please replace its usage with implicit namespaces (PEP 420).
#
#         See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages for details.
#         ********************************************************************************
#
# !!
#   ep.load()(self, ep.name, value)
# running build
# running build_py
# copying atomsci/__init__.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci
# copying atomsci/ddm/__init__.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm
# copying atomsci/ddm/pipeline/GeneticAlgorithm.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/MultitaskScaffoldSplit.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/__init__.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/ave_splitter.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/chem_diversity.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/compare_models.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/dist_metrics.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/diversity_plots.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/feature_importance.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/featurization.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/hyper_perf_plots.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/model_datasets.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/model_pipeline.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/model_tracker.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/model_wrapper.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/parameter_parser.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/perf_data.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/perf_plots.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/predict_from_model.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/splitting.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/temporal_splitter.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/transformations.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/pipeline
# copying atomsci/ddm/utils/__init__.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/checksum_utils.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/compare_split_csv.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/compare_splits_plots.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/curate_data.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/data_curation_functions.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/datastore_functions.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/file_utils.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/genTestset.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/hyperparam_search_wrapper.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/llnl_utils.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/many_to_one.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/model_file_reader.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/model_retrain.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/model_version_utils.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/open-docs.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/patch_model_dataset_key.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/process_slurm.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/pubchem_utils.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/rdkit_easy.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/split_response_dist_plots.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/struct_utils.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# copying atomsci/ddm/utils/test_utils.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# running egg_info
# writing /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/atomsci_ampl.egg-info/PKG-INFO
# writing dependency_links to /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/atomsci_ampl.egg-info/dependency_links.txt
# writing namespace_packages to /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/atomsci_ampl.egg-info/namespace_packages.txt
# writing top-level names to /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/atomsci_ampl.egg-info/top_level.txt
# reading manifest file '/home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/atomsci_ampl.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching 'atomsci/*/*.yaml'
# adding license file 'LICENSE'
# adding license file 'NOTICE'
# writing manifest file '/home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/atomsci_ampl.egg-info/SOURCES.txt'
# /opt/conda/lib/python3.10/site-packages/setuptools/command/build_py.py:207: _Warning: Package 'atomsci.ddm.data' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'atomsci.ddm.data' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'atomsci.ddm.data' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'atomsci.ddm.data' to be distributed and are
#         already explicitly excluding 'atomsci.ddm.data' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# copying atomsci/ddm/data/descriptor_sets_sources_by_descr_type.csv -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/data
# copying atomsci/ddm/utils/open-docs.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/lib/atomsci/ddm/utils
# running bdist_wheel
# /opt/conda/lib/python3.10/site-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# installing to /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel
# running install
# running install_lib
# Skipping installation of /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/__init__.py (namespace package)
# copying atomsci/ddm/__init__.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm
# copying atomsci/ddm/pipeline/GeneticAlgorithm.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/MultitaskScaffoldSplit.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/__init__.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/ave_splitter.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/chem_diversity.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/dist_metrics.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/feature_importance.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/hyper_perf_plots.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/model_pipeline.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/model_wrapper.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/perf_data.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/perf_plots.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/splitting.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/transformations.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/compare_models.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/diversity_plots.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/featurization.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/model_datasets.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/model_tracker.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/parameter_parser.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/predict_from_model.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/pipeline/temporal_splitter.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/pipeline
# copying atomsci/ddm/utils/__init__.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/checksum_utils.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/compare_split_csv.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/compare_splits_plots.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/curate_data.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/data_curation_functions.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/datastore_functions.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/file_utils.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/genTestset.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/hyperparam_search_wrapper.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/llnl_utils.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/many_to_one.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/model_file_reader.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/model_retrain.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/model_version_utils.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/patch_model_dataset_key.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/process_slurm.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/pubchem_utils.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/rdkit_easy.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/split_response_dist_plots.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/struct_utils.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/test_utils.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/utils/open-docs.py -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/utils
# copying atomsci/ddm/data/descriptor_sets_sources_by_descr_type.csv -> /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci/ddm/data
# running install_egg_info
# Copying /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/atomsci_ampl.egg-info to /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci_ampl-1.6.0-py3.10.egg-info
# Installing /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci_ampl-1.6.0-py3.10-nspkg.pth
# running install_scripts
# creating /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel/atomsci_ampl-1.6.0.dist-info/WHEEL
# creating '/home/sagemaker-user/BigDataSys-Project8/github/AMPL.dist/atomsci_ampl-1.6.0-py3-none-any.whl' and adding '/home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel' to it
# adding 'atomsci_ampl-1.6.0-py3.10-nspkg.pth'
# adding 'atomsci/ddm/__init__.py'
# adding 'atomsci/ddm/data/descriptor_sets_sources_by_descr_type.csv'
# adding 'atomsci/ddm/pipeline/GeneticAlgorithm.py'
# adding 'atomsci/ddm/pipeline/MultitaskScaffoldSplit.py'
# adding 'atomsci/ddm/pipeline/__init__.py'
# adding 'atomsci/ddm/pipeline/ave_splitter.py'
# adding 'atomsci/ddm/pipeline/chem_diversity.py'
# adding 'atomsci/ddm/pipeline/compare_models.py'
# adding 'atomsci/ddm/pipeline/dist_metrics.py'
# adding 'atomsci/ddm/pipeline/diversity_plots.py'
# adding 'atomsci/ddm/pipeline/feature_importance.py'
# adding 'atomsci/ddm/pipeline/featurization.py'
# adding 'atomsci/ddm/pipeline/hyper_perf_plots.py'
# adding 'atomsci/ddm/pipeline/model_datasets.py'
# adding 'atomsci/ddm/pipeline/model_pipeline.py'
# adding 'atomsci/ddm/pipeline/model_tracker.py'
# adding 'atomsci/ddm/pipeline/model_wrapper.py'
# adding 'atomsci/ddm/pipeline/parameter_parser.py'
# adding 'atomsci/ddm/pipeline/perf_data.py'
# adding 'atomsci/ddm/pipeline/perf_plots.py'
# adding 'atomsci/ddm/pipeline/predict_from_model.py'
# adding 'atomsci/ddm/pipeline/splitting.py'
# adding 'atomsci/ddm/pipeline/temporal_splitter.py'
# adding 'atomsci/ddm/pipeline/transformations.py'
# adding 'atomsci/ddm/utils/__init__.py'
# adding 'atomsci/ddm/utils/checksum_utils.py'
# adding 'atomsci/ddm/utils/compare_split_csv.py'
# adding 'atomsci/ddm/utils/compare_splits_plots.py'
# adding 'atomsci/ddm/utils/curate_data.py'
# adding 'atomsci/ddm/utils/data_curation_functions.py'
# adding 'atomsci/ddm/utils/datastore_functions.py'
# adding 'atomsci/ddm/utils/file_utils.py'
# adding 'atomsci/ddm/utils/genTestset.py'
# adding 'atomsci/ddm/utils/hyperparam_search_wrapper.py'
# adding 'atomsci/ddm/utils/llnl_utils.py'
# adding 'atomsci/ddm/utils/many_to_one.py'
# adding 'atomsci/ddm/utils/model_file_reader.py'
# adding 'atomsci/ddm/utils/model_retrain.py'
# adding 'atomsci/ddm/utils/model_version_utils.py'
# adding 'atomsci/ddm/utils/open-docs.py'
# adding 'atomsci/ddm/utils/patch_model_dataset_key.py'
# adding 'atomsci/ddm/utils/process_slurm.py'
# adding 'atomsci/ddm/utils/pubchem_utils.py'
# adding 'atomsci/ddm/utils/rdkit_easy.py'
# adding 'atomsci/ddm/utils/split_response_dist_plots.py'
# adding 'atomsci/ddm/utils/struct_utils.py'
# adding 'atomsci/ddm/utils/test_utils.py'
# adding 'atomsci_ampl-1.6.0.dist-info/LICENSE'
# adding 'atomsci_ampl-1.6.0.dist-info/METADATA'
# adding 'atomsci_ampl-1.6.0.dist-info/NOTICE'
# adding 'atomsci_ampl-1.6.0.dist-info/WHEEL'
# adding 'atomsci_ampl-1.6.0.dist-info/namespace_packages.txt'
# adding 'atomsci_ampl-1.6.0.dist-info/top_level.txt'
# adding 'atomsci_ampl-1.6.0.dist-info/RECORD'
# removing /home/sagemaker-user/BigDataSys-Project8/github/AMPL.build/ampl/bdist.linux-x86_64/wheel
# DIR: /home/sagemaker-user/BigDataSys-Project8/github/AMPL
# Using pip 23.3.2 from /opt/conda/lib/python3.10/site-packages/pip (python 3.10)
# Looking in links: /home/sagemaker-user/BigDataSys-Project8/github/AMPL.dist
# Processing /home/sagemaker-user/BigDataSys-Project8/github/AMPL.dist/atomsci_ampl-1.6.0-py3-none-any.whl
# Installing collected packages: atomsci_ampl
# Successfully installed atomsci_ampl-1.6.0

# %% [markdown]
# ## Data curation
#
# We then download and do very simple curation to the related dataset.
#
# We need to set the directory we want to save files to. Next we download the dataset.

# %%
working_dir = '/content'

# %%
import io
url = 'https://raw.githubusercontent.com/deepchem/deepchem/master/datasets/delaney-processed.csv'
download = requests.get(url).content

# %%
# Reading the downloaded content and turning it into a pandas dataframe
raw_df = pd.read_csv(io.StringIO(download.decode('utf-8')), sep=',', header=0 )

# %% [markdown]
# Next, we load the downloaded dataset, and process the compound structures:

# %%
data_orig = raw_df

# %%
raw_df.columns
# Out:
# Index(['Compound ID', 'ESOL predicted log solubility in mols per litre',
#        'Minimum Degree', 'Molecular Weight', 'Number of H-Bond Donors',
#        'Number of Rings', 'Number of Rotatable Bonds', 'Polar Surface Area',
#        'measured log solubility in mols per litre', 'smiles'],
#       dtype='object')

# %%
raw_df.head(5)
# Out:
#   Compound ID  ESOL predicted log solubility in mols per litre  \
# 0   Amigdalin                                           -0.974
# 1    Fenfuram                                           -2.885
# 2      citral                                           -2.579
# 3      Picene                                           -6.618
# 4   Thiophene                                           -2.232
#
#    Minimum Degree  Molecular Weight  Number of H-Bond Donors  Number of Rings  \
# 0               1           457.432                        7                3
# 1               1           201.225                        1                2
# 2               1           152.237                        0                0
# 3               2           278.354                        0                5
# 4               2            84.143                        0                1
#
#    Number of Rotatable Bonds  Polar Surface Area  \
# 0                          7              202.32
# 1                          2               42.24
# 2                          4               17.07
# 3                          0                0.00
# 4                          0                0.00
#
#    measured log solubility in mols per litre  \
# 0                                      -0.77
# 1                                      -3.30
# 2                                      -2.06
# 3                                      -7.87
# 4                                      -1.33
#
#                                               smiles
# 0  OCC3OC(OCC2OC(OC(C#N)c1ccccc1)C(O)C(O)C2O)C(O)...
# 1                             Cc1occc1C(=O)Nc2ccccc2
# 2                               CC(C)=CCCC(C)=CC(=O)
# 3                 c1ccc2c(c1)ccc3c2ccc4c5ccccc5ccc43
# 4                                            c1ccsc1

# %%
# base_smiles_from_smiles:
# Generate a standardized SMILES, InChI keys for dataset with curation and structure modules.
# RDkit modules are used to process the SMILES strings

# Default Arg options:
# useIsomericSmiles = True
# removeCharges = False

raw_df['rdkit_smiles'] = raw_df['smiles'].apply(curate_data.base_smiles_from_smiles)

# %% [markdown]
# ## What happened after calling `base_smiles_from_smiles`?
# Also remember the column name of the `rdkit_smiles`, we will use the standardized smiles later as input in our model calculations

# %%
raw_df.head(4)
# Out:
#   Compound ID  ESOL predicted log solubility in mols per litre  \
# 0   Amigdalin                                           -0.974
# 1    Fenfuram                                           -2.885
# 2      citral                                           -2.579
# 3      Picene                                           -6.618
#
#    Minimum Degree  Molecular Weight  Number of H-Bond Donors  Number of Rings  \
# 0               1           457.432                        7                3
# 1               1           201.225                        1                2
# 2               1           152.237                        0                0
# 3               2           278.354                        0                5
#
#    Number of Rotatable Bonds  Polar Surface Area  \
# 0                          7              202.32
# 1                          2               42.24
# 2                          4               17.07
# 3                          0                0.00
#
#    measured log solubility in mols per litre  \
# 0                                      -0.77
# 1                                      -3.30
# 2                                      -2.06
# 3                                      -7.87
#
#                                               smiles  \
# 0  OCC3OC(OCC2OC(OC(C#N)c1ccccc1)C(O)C(O)C2O)C(O)...
# 1                             Cc1occc1C(=O)Nc2ccccc2
# 2                               CC(C)=CCCC(C)=CC(=O)
# 3                 c1ccc2c(c1)ccc3c2ccc4c5ccccc5ccc43
#
#                                         rdkit_smiles
# 0  N#CC(OC1OC(COC2OC(CO)C(O)C(O)C2O)C(O)C(O)C1O)c...
# 1                             Cc1occc1C(=O)Nc1ccccc1
# 2                                 CC(C)=CCCC(C)=CC=O
# 3                 c1ccc2c(c1)ccc1c2ccc2c3ccccc3ccc21

# %% [markdown]
# ## In the following cell, we will call smiles_to_inchi_key to create InChi Keys
#
# We will create InChi key (https://en.wikipedia.org/wiki/International_Chemical_Identifier) from SMILES string using RDKit. Note if for some reason, the convertion fails, you will see None as output

# %%
raw_df['inchi_key'] = raw_df['smiles'].apply(struct_utils.smiles_to_inchi_key)
# Out:
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Charges were rearranged
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Charges were rearranged
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Charges were rearranged
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Charges were rearranged; Omitted undefined stereo
#
# [21:35:27] WARNING: Charges were rearranged
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Charges were rearranged
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Charges were rearranged
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Charges were rearranged
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Charges were rearranged
#
# [21:35:27] WARNING: Charges were rearranged
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Charges were rearranged
#
# [21:35:27] WARNING: Charges were rearranged
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Charges were rearranged
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Charges were rearranged
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Charges were rearranged
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Charges were rearranged
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Charges were rearranged
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Charges were rearranged
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Charges were rearranged
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Charges were rearranged
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Charges were rearranged
#
# [21:35:27] WARNING: Charges were rearranged
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Charges were rearranged
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Charges were rearranged
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Charges were rearranged
#
# [21:35:27] WARNING: Charges were rearranged
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Charges were rearranged
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Charges were rearranged
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Charges were rearranged; Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Charges were rearranged
#
# [21:35:27] WARNING: Charges were rearranged
#
# [21:35:27] WARNING: Charges were rearranged
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Charges were rearranged
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Charges were rearranged
#
# [21:35:27] WARNING: Charges were rearranged
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Charges were rearranged
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Charges were rearranged
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Charges were rearranged
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Charges were rearranged; Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Charges were rearranged
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Charges were rearranged
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Charges were rearranged
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:27] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Charges were rearranged
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Charges were rearranged
#
# [21:35:28] WARNING: Charges were rearranged
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Charges were rearranged
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Charges were rearranged
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Charges were rearranged
#
# [21:35:28] WARNING: Charges were rearranged
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Charges were rearranged
#
# [21:35:28] WARNING: Charges were rearranged
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Charges were rearranged
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Charges were rearranged
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Charges were rearranged
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Charges were rearranged
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Charges were rearranged
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Charges were rearranged; Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Charges were rearranged
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Charges were rearranged
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo
#
# [21:35:28] WARNING: Omitted undefined stereo

# %% [markdown]
# ## Note the addition of new column, inchi_key

# %%
raw_df.head(3)
# Out:
#   Compound ID  ESOL predicted log solubility in mols per litre  \
# 0   Amigdalin                                           -0.974
# 1    Fenfuram                                           -2.885
# 2      citral                                           -2.579
#
#    Minimum Degree  Molecular Weight  Number of H-Bond Donors  Number of Rings  \
# 0               1           457.432                        7                3
# 1               1           201.225                        1                2
# 2               1           152.237                        0                0
#
#    Number of Rotatable Bonds  Polar Surface Area  \
# 0                          7              202.32
# 1                          2               42.24
# 2                          4               17.07
#
#    measured log solubility in mols per litre  \
# 0                                      -0.77
# 1                                      -3.30
# 2                                      -2.06
#
#                                               smiles  \
# 0  OCC3OC(OCC2OC(OC(C#N)c1ccccc1)C(O)C(O)C2O)C(O)...
# 1                             Cc1occc1C(=O)Nc2ccccc2
# 2                               CC(C)=CCCC(C)=CC(=O)
#
#                                         rdkit_smiles  \
# 0  N#CC(OC1OC(COC2OC(CO)C(O)C(O)C2O)C(O)C(O)C1O)c...
# 1                             Cc1occc1C(=O)Nc1ccccc1
# 2                                 CC(C)=CCCC(C)=CC=O
#
#                      inchi_key
# 0  XUCIJNAGGSZNQT-UHFFFAOYSA-N
# 1  JFSPBVWPKOEZCB-UHFFFAOYSA-N
# 2  WTEVQBCEXWBHNA-UHFFFAOYSA-N

# %%
data = raw_df
data['compound_id'] = data['inchi_key']

# %% [markdown]
# ## Let us review the dataset

# %%
data.head(3)
# Out:
#   Compound ID  ESOL predicted log solubility in mols per litre  \
# 0   Amigdalin                                           -0.974
# 1    Fenfuram                                           -2.885
# 2      citral                                           -2.579
#
#    Minimum Degree  Molecular Weight  Number of H-Bond Donors  Number of Rings  \
# 0               1           457.432                        7                3
# 1               1           201.225                        1                2
# 2               1           152.237                        0                0
#
#    Number of Rotatable Bonds  Polar Surface Area  \
# 0                          7              202.32
# 1                          2               42.24
# 2                          4               17.07
#
#    measured log solubility in mols per litre  \
# 0                                      -0.77
# 1                                      -3.30
# 2                                      -2.06
#
#                                               smiles  \
# 0  OCC3OC(OCC2OC(OC(C#N)c1ccccc1)C(O)C(O)C2O)C(O)...
# 1                             Cc1occc1C(=O)Nc2ccccc2
# 2                               CC(C)=CCCC(C)=CC(=O)
#
#                                         rdkit_smiles  \
# 0  N#CC(OC1OC(COC2OC(CO)C(O)C(O)C2O)C(O)C(O)C1O)c...
# 1                             Cc1occc1C(=O)Nc1ccccc1
# 2                                 CC(C)=CCCC(C)=CC=O
#
#                      inchi_key                  compound_id
# 0  XUCIJNAGGSZNQT-UHFFFAOYSA-N  XUCIJNAGGSZNQT-UHFFFAOYSA-N
# 1  JFSPBVWPKOEZCB-UHFFFAOYSA-N  JFSPBVWPKOEZCB-UHFFFAOYSA-N
# 2  WTEVQBCEXWBHNA-UHFFFAOYSA-N  WTEVQBCEXWBHNA-UHFFFAOYSA-N

# %% [markdown]
# ## Let us view some molecules

# %%
data['smiles'][0:10]
# Out:
# 0    OCC3OC(OCC2OC(OC(C#N)c1ccccc1)C(O)C(O)C2O)C(O)...
# 1                               Cc1occc1C(=O)Nc2ccccc2
# 2                                 CC(C)=CCCC(C)=CC(=O)
# 3                   c1ccc2c(c1)ccc3c2ccc4c5ccccc5ccc43
# 4                                              c1ccsc1
# 5                                       c2ccc1scnc1c2
# 6                   Clc1cc(Cl)c(c(Cl)c1)c2c(Cl)cccc2Cl
# 7                     CC12CCC3C(CCc4cc(O)ccc34)C2CCC1O
# 8       ClC4=C(Cl)C5(Cl)C3C1CC(C2OC12)C3C4(Cl)C5(Cl)Cl
# 9     COc5cc4OCC3Oc2c1CC(Oc1ccc2C(=O)C3c4cc5OC)C(C)=C
# Name: smiles, dtype: object

# %%
from rdkit import Chem
from rdkit.Chem import Draw
from itertools import islice

molecules = [Chem.MolFromSmiles(smiles) for smiles in islice(data['smiles'], 9)]

Draw.MolsToGridImage(molecules)

# %% [markdown]
# The next step is to address the case where we have multiple measurements for a single structure (by RDkit canonical SMILEs string). We have a function in the `curate_data()` module to address the processing of compounds. The function parameters are listed below along with an explanation of each parameter:

# %%
data
# Out:
#          Compound ID  ESOL predicted log solubility in mols per litre  \
# 0          Amigdalin                                           -0.974
# 1           Fenfuram                                           -2.885
# 2             citral                                           -2.579
# 3             Picene                                           -6.618
# 4          Thiophene                                           -2.232
# ...              ...                                              ...
# 1123       halothane                                           -2.608
# 1124          Oxamyl                                           -0.908
# 1125       Thiometon                                           -3.323
# 1126  2-Methylbutane                                           -2.245
# 1127        Stirofos                                           -4.320
#
#       Minimum Degree  Molecular Weight  Number of H-Bond Donors  \
# 0                  1           457.432                        7
# 1                  1           201.225                        1
# 2                  1           152.237                        0
# 3                  2           278.354                        0
# 4                  2            84.143                        0
# ...              ...               ...                      ...
# 1123               1           197.381                        0
# 1124               1           219.266                        1
# 1125               1           246.359                        0
# 1126               1            72.151                        0
# 1127               1           365.964                        0
#
#       Number of Rings  Number of Rotatable Bonds  Polar Surface Area  \
# 0                   3                          7              202.32
# 1                   2                          2               42.24
# 2                   0                          4               17.07
# 3                   5                          0                0.00
# 4                   1                          0                0.00
# ...               ...                        ...                 ...
# 1123                0                          0                0.00
# 1124                0                          1               71.00
# 1125                0                          7               18.46
# 1126                0                          1                0.00
# 1127                1                          5               44.76
#
#       measured log solubility in mols per litre  \
# 0                                        -0.770
# 1                                        -3.300
# 2                                        -2.060
# 3                                        -7.870
# 4                                        -1.330
# ...                                         ...
# 1123                                     -1.710
# 1124                                      0.106
# 1125                                     -3.091
# 1126                                     -3.180
# 1127                                     -4.522
#
#                                                  smiles  \
# 0     OCC3OC(OCC2OC(OC(C#N)c1ccccc1)C(O)C(O)C2O)C(O)...
# 1                                Cc1occc1C(=O)Nc2ccccc2
# 2                                  CC(C)=CCCC(C)=CC(=O)
# 3                    c1ccc2c(c1)ccc3c2ccc4c5ccccc5ccc43
# 4                                               c1ccsc1
# ...                                                 ...
# 1123                                   FC(F)(F)C(Cl)Br
# 1124                          CNC(=O)ON=C(SC)C(=O)N(C)C
# 1125                                  CCSCCSP(=S)(OC)OC
# 1126                                            CCC(C)C
# 1127              COP(=O)(OC)OC(=CCl)c1cc(Cl)c(Cl)cc1Cl
#
#                                            rdkit_smiles  \
# 0     N#CC(OC1OC(COC2OC(CO)C(O)C(O)C2O)C(O)C(O)C1O)c...
# 1                                Cc1occc1C(=O)Nc1ccccc1
# 2                                    CC(C)=CCCC(C)=CC=O
# 3                    c1ccc2c(c1)ccc1c2ccc2c3ccccc3ccc21
# 4                                               c1ccsc1
# ...                                                 ...
# 1123                                    FC(F)(F)C(Cl)Br
# 1124                          CNC(=O)ON=C(SC)C(=O)N(C)C
# 1125                                  CCSCCSP(=S)(OC)OC
# 1126                                            CCC(C)C
# 1127              COP(=O)(OC)OC(=CCl)c1cc(Cl)c(Cl)cc1Cl
#
#                         inchi_key                  compound_id
# 0     XUCIJNAGGSZNQT-UHFFFAOYSA-N  XUCIJNAGGSZNQT-UHFFFAOYSA-N
# 1     JFSPBVWPKOEZCB-UHFFFAOYSA-N  JFSPBVWPKOEZCB-UHFFFAOYSA-N
# 2     WTEVQBCEXWBHNA-UHFFFAOYSA-N  WTEVQBCEXWBHNA-UHFFFAOYSA-N
# 3     GBROPGWFBFCKAG-UHFFFAOYSA-N  GBROPGWFBFCKAG-UHFFFAOYSA-N
# 4     YTPLMLYBLZKORZ-UHFFFAOYSA-N  YTPLMLYBLZKORZ-UHFFFAOYSA-N
# ...                           ...                          ...
# 1123  BCQZXOMGPXTTIC-UHFFFAOYSA-N  BCQZXOMGPXTTIC-UHFFFAOYSA-N
# 1124  KZAUOCCYDRDERY-UHFFFAOYSA-N  KZAUOCCYDRDERY-UHFFFAOYSA-N
# 1125  OPASCBHCTNRLRM-UHFFFAOYSA-N  OPASCBHCTNRLRM-UHFFFAOYSA-N
# 1126  QWTDNUCVQCZILF-UHFFFAOYSA-N  QWTDNUCVQCZILF-UHFFFAOYSA-N
# 1127  UBCKGWBNUIFUST-UHFFFAOYSA-N  UBCKGWBNUIFUST-UHFFFAOYSA-N
#
# [1128 rows x 13 columns]

# %%
# del_features = ['VALUE_NUM_mean', 'VALUE_NUM_std', 'Perc_Var', 'Remove_BadDuplicate']
# data.drop(labels=del_features, axis=1, inplace=True)

# %%
# column: Response values column
column = 'measured log solubility in mols per litre'

# tolerance: Percentage of individual respsonse values allowed to be different
# from the average to be included in averaging
tolerance = 10

# list_bad_duplicates: Print structures with bad duplicates
list_bad_duplicates = 'Yes'

# max_std: Maximum allowed standard deviation for computed average response value
# NOTE: In this example, we set this value very high to disable this feature
max_std = 100000

# compound_id: Compound ID column
compound_id = 'compound_id'

# smiles_col: SMILES column
smiles_col = 'rdkit_smiles'

# call the method `average_and_remove_duplicates` which changes the data and returns
# the new object as curated_df, in this case


curated_df = curate_data.average_and_remove_duplicates(column,
                                                       tolerance,
                                                       list_bad_duplicates,
                                                       data,
                                                       max_std,
                                                       compound_id=compound_id,
                                                       smiles_col=smiles_col)
# Out:
# Bad duplicates removed from dataset
# Dataframe size (1126, 17)
# List of 'bad' duplicates removed
#                      compound_id  measured log solubility in mols per litre  \
# 233  FBPFZTCFMRRESA-UHFFFAOYSA-N                                       0.06
# 276  FBPFZTCFMRRESA-UHFFFAOYSA-N                                       1.09
#
#      VALUE_NUM_mean   Perc_Var  VALUE_NUM_std
# 233           0.575  89.565217        0.72832
# 276           0.575  89.565217        0.72832
#
# Dataset de-duplicated
# Dataframe size (1116, 17)
# New column created with averaged values:  VALUE_NUM_mean

# %%
data.head(3)
# Out:
#   Compound ID  ESOL predicted log solubility in mols per litre  \
# 0   Amigdalin                                           -0.974
# 1    Fenfuram                                           -2.885
# 2      citral                                           -2.579
#
#    Minimum Degree  Molecular Weight  Number of H-Bond Donors  Number of Rings  \
# 0               1           457.432                        7                3
# 1               1           201.225                        1                2
# 2               1           152.237                        0                0
#
#    Number of Rotatable Bonds  Polar Surface Area  \
# 0                          7              202.32
# 1                          2               42.24
# 2                          4               17.07
#
#    measured log solubility in mols per litre  \
# 0                                      -0.77
# 1                                      -3.30
# 2                                      -2.06
#
#                                               smiles  \
# 0  OCC3OC(OCC2OC(OC(C#N)c1ccccc1)C(O)C(O)C2O)C(O)...
# 1                             Cc1occc1C(=O)Nc2ccccc2
# 2                               CC(C)=CCCC(C)=CC(=O)
#
#                                         rdkit_smiles  \
# 0  N#CC(OC1OC(COC2OC(CO)C(O)C(O)C2O)C(O)C(O)C1O)c...
# 1                             Cc1occc1C(=O)Nc1ccccc1
# 2                                 CC(C)=CCCC(C)=CC=O
#
#                      inchi_key                  compound_id
# 0  XUCIJNAGGSZNQT-UHFFFAOYSA-N  XUCIJNAGGSZNQT-UHFFFAOYSA-N
# 1  JFSPBVWPKOEZCB-UHFFFAOYSA-N  JFSPBVWPKOEZCB-UHFFFAOYSA-N
# 2  WTEVQBCEXWBHNA-UHFFFAOYSA-N  WTEVQBCEXWBHNA-UHFFFAOYSA-N

# %%
curated_df.head(3)
# Out:
#   Compound ID  ESOL predicted log solubility in mols per litre  \
# 0   Amigdalin                                           -0.974
# 1    Fenfuram                                           -2.885
# 2      citral                                           -2.579
#
#    Minimum Degree  Molecular Weight  Number of H-Bond Donors  Number of Rings  \
# 0               1           457.432                        7                3
# 1               1           201.225                        1                2
# 2               1           152.237                        0                0
#
#    Number of Rotatable Bonds  Polar Surface Area  \
# 0                          7              202.32
# 1                          2               42.24
# 2                          4               17.07
#
#    measured log solubility in mols per litre  \
# 0                                      -0.77
# 1                                      -3.30
# 2                                      -2.06
#
#                                               smiles  \
# 0  OCC3OC(OCC2OC(OC(C#N)c1ccccc1)C(O)C(O)C2O)C(O)...
# 1                             Cc1occc1C(=O)Nc2ccccc2
# 2                               CC(C)=CCCC(C)=CC(=O)
#
#                                         rdkit_smiles  \
# 0  N#CC(OC1OC(COC2OC(CO)C(O)C(O)C2O)C(O)C(O)C1O)c...
# 1                             Cc1occc1C(=O)Nc1ccccc1
# 2                                 CC(C)=CCCC(C)=CC=O
#
#                      inchi_key                  compound_id  VALUE_NUM_mean  \
# 0  XUCIJNAGGSZNQT-UHFFFAOYSA-N  XUCIJNAGGSZNQT-UHFFFAOYSA-N           -0.77
# 1  JFSPBVWPKOEZCB-UHFFFAOYSA-N  JFSPBVWPKOEZCB-UHFFFAOYSA-N           -3.30
# 2  WTEVQBCEXWBHNA-UHFFFAOYSA-N  WTEVQBCEXWBHNA-UHFFFAOYSA-N           -2.06
#
#    VALUE_NUM_std  Perc_Var  Remove_BadDuplicate
# 0            NaN      -0.0                    0
# 1            NaN      -0.0                    0
# 2            NaN      -0.0                    0

# %%
import os
folder_name = 'BigDataSys-Project8'
curated_file = os.path.join('/home/sagemaker-user/BigDataSys-Project8', 'delaney_curated.csv')
curated_df.to_csv(curated_file, index=False)

# %% [markdown]
# Now that we have a curated dataset, we decide what type of featurizer and model we would like. See documentation for all available options. We also set the name of the new averaged response value column.

# %%
featurizer = 'ecfp'
model_type = 'RF'
response_cols = ['VALUE_NUM_mean']

# %% [markdown]
# Next we set up the parameters for our model. We set datastore and save_results to False to indicate that we are reading the input file and saving the results directly to the file system. There are a wide range of settable parameters; see the documentation for more details.

# %%
smiles_col
# Out:
# 'rdkit_smiles'

# %%
params={"datastore": "False",
        "save_results": "False",
        "id_col": compound_id,
        "smiles_col": smiles_col,
        "response_cols": response_cols,
        "featurizer": featurizer,
        "model_type": model_type,
        "result_dir": working_dir,
        "dataset_key": curated_file}

# %% [markdown]
# We use parse.wrapper to process our input configuration. We then build the model pipeline, train the model, and plot the predicted versus true values for our train, valid, test sets.

# %%
pparams = parse.wrapper(params)

# %% [markdown]
# ## Details of the following code chunk
#  Here we create instances of the class ModelPipeline, called `MP`. The instance `MP` has access to data attributes and methods of the class.

# %%
MP = mp.ModelPipeline(pparams)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# /home/sagemaker-user/BigDataSys-Project8/10_Delaney_Solubility_Prediction_AWS.ipynb Cell 49 line 1
# ----> <a href='vscode-notebook-cell://o3m1pooahqidjzi.studio.us-east-1.sagemaker.aws/home/sagemaker-user/BigDataSys-Project8/10_Delaney_Solubility_Prediction_AWS.ipynb#X62sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> MP = mp.ModelPipeline(pparams)
#
# File /opt/conda/lib/python3.10/site-packages/atomsci/ddm/pipeline/model_pipeline.py:233, in ModelPipeline.__init__(self, params, ds_client, mlmt_client)
#     226     self.params.output_dir = os.path.join(self.params.result_dir, self.params.dataset_name, '%s_%s_%s_%s' %
#     227                                           (
#     228                                             self.params.model_type,
#     229                                               self.params.featurizer,
#     230                                               self.params.splitter, self.params.prediction_type),
#     231                                           self.params.model_uuid)
#     232 if not os.path.isdir(self.params.output_dir):
# --> 233     os.makedirs(self.params.output_dir, exist_ok=True)
#     234 self.output_dir = self.params.output_dir
#     235 if self.params.model_tarball_path is None:
#
# File /opt/conda/lib/python3.10/os.py:215, in makedirs(name, mode, exist_ok)
#     213 if head and tail and not path.exists(head):
#     214     try:
# --> 215         makedirs(head, exist_ok=exist_ok)
#     216     except FileExistsError:
#     217         # Defeats race condition when another thread created the path
#     218         pass
#
# File /opt/conda/lib/python3.10/os.py:215, in makedirs(name, mode, exist_ok)
#     213 if head and tail and not path.exists(head):
#     214     try:
# --> 215         makedirs(head, exist_ok=exist_ok)
#     216     except FileExistsError:
#     217         # Defeats race condition when another thread created the path
#     218         pass
#
# File /opt/conda/lib/python3.10/os.py:215, in makedirs(name, mode, exist_ok)
#     213 if head and tail and not path.exists(head):
#     214     try:
# --> 215         makedirs(head, exist_ok=exist_ok)
#     216     except FileExistsError:
#     217         # Defeats race condition when another thread created the path
#     218         pass
#
# File /opt/conda/lib/python3.10/os.py:225, in makedirs(name, mode, exist_ok)
#     223         return
#     224 try:
# --> 225     mkdir(name, mode)
#     226 except OSError:
#     227     # Cannot rely on checking for EEXIST, since the operating system
#     228     # could give priority to other errors like EACCES or EROFS
#     229     if not exist_ok or not path.isdir(name):
#
# PermissionError: [Errno 13] Permission denied: '/content'

# %% [markdown]
# ## Use `dir` function to explore data attributes and functions associated with the class.
#
# The output is a list of data object attributes. Note the attributes that are surrounded by double-underscore (ex., `__le__`) are for internal use
# and you dont have to worry about them. The regular (non underscore attributes) are of your concern. In the example shown below, these attributes start
# with `'create_model_metadata'`

# %%
dir(MP)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/sagemaker-user/BigDataSys-Project8/10_Delaney_Solubility_Prediction_AWS.ipynb Cell 50 line 1
# ----> <a href='vscode-notebook-cell://o3m1pooahqidjzi.studio.us-east-1.sagemaker.aws/home/sagemaker-user/BigDataSys-Project8/10_Delaney_Solubility_Prediction_AWS.ipynb#X64sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> dir(MP)
#
# NameError: name 'MP' is not defined

# %% [markdown]
# ### Train_model:
# Build model described by self.params on the training dataset described by self.params.Generate predictions for the training, validation, and test datasets, and save the predictions and performance metrics in the model results DB or in a JSON file.
#
# ## Note `train_model` is a method of class `ModelPipeline`. If you are using COLAB, mouse-over the `MP.train_model()` to view the source code

# %%
import atomsci.ddm.pipeline.model_pipeline as mp
#mp.ampl_version

# %%
MP.train_model()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/sagemaker-user/BigDataSys-Project8/10_Delaney_Solubility_Prediction_AWS.ipynb Cell 53 line 1
# ----> <a href='vscode-notebook-cell://o3m1pooahqidjzi.studio.us-east-1.sagemaker.aws/home/sagemaker-user/BigDataSys-Project8/10_Delaney_Solubility_Prediction_AWS.ipynb#Y100sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> MP.train_model()
#
# NameError: name 'MP' is not defined

# %%
pp.plot_pred_vs_actual(MP)

# %%
pparams
# MP.train_model()
# Out:
# Namespace(bucket='public', dataset_key='/content/delaney_curated.csv', dataset_name='delaney_curated', dataset_oid=None, datastore=False, id_col='compound_id', min_compound_number=200, response_cols=['VALUE_NUM_mean'], save_results=False, smiles_col='rdkit_smiles', max_dataset_rows=0, autoencoder_bucket=None, autoencoder_key=None, autoencoder_type='molvae', mol_vae_model_file=None, class_number=2, class_name=None, descriptor_bucket='public', descriptor_key=None, descriptor_oid=None, descriptor_spec_bucket='', descriptor_spec_key='/usr/local/lib/python3.10/dist-packages/atomsci/ddm/data/descriptor_sets_sources_by_descr_type.csv', descriptor_type='moe', moe_threads=-1, ecfp_radius=2, ecfp_size=1024, embedding_model_uuid=None, embedding_model_collection=None, embedding_model_path=None, featurizer='ecfp', model_choice_score_type='r2', model_type='RF', prediction_type='regression', previously_featurized=True, uncertainty=True, verbose=False, optimizer_type='adam', mordred_cpus=None, baseline_epoch=30, batch_size=50, early_stopping_patience=30, early_stopping_min_improvement=0.0, bias_init_consts=None, dropouts=None, layer_sizes=None, learning_rate=0.0005, max_epochs=30, weight_decay_penalty=0.0001, weight_decay_penalty_type='l2', weight_init_stddevs=None, is_ki=False, ki_convert_ratio=None, loss_func='poisson', rf_estimators=500, rf_max_depth=None, rf_max_features=32, base_splitter='scaffold', butina_cutoff=0.6, cutoff_date=None, date_col=None, num_folds=5, previously_split=False, split_strategy='train_valid_test', split_test_frac=0.1, split_uuid=None, split_valid_frac=0.1, splitter='scaffold', mtss_num_super_scaffolds=40, mtss_num_generations=20, mtss_num_pop=100, mtss_train_test_dist_weight=1.0, mtss_train_valid_dist_weight=1.0, mtss_split_fraction_weight=1.0, feature_transform_type='normalization', response_transform_type='normalization', weight_transform_type=None, transformer_bucket='', transformer_key='/content/delaney_curated/RF_ecfp_scaffold_regression/743c9e45-04e2-495c-a378-24f7e910a127/transformers.pkl', transformer_oid='', transformers=True, umap_dim=10, umap_metric='euclidean', umap_min_dist=0.05, umap_neighbors=20, umap_targ_wt=0.0, xgb_colsample_bytree=1.0, xgb_gamma=0.0, xgb_learning_rate=0.1, xgb_max_depth=6, xgb_min_child_weight=1.0, xgb_n_estimators=100, xgb_subsample=1.0, collection_name='model_tracker', data_owner='gsk', data_owner_group='gsk_craa', model_bucket='public', model_dataset_oid=None, model_filter=None, model_uuid='743c9e45-04e2-495c-a378-24f7e910a127', output_dir='/content/delaney_curated/RF_ecfp_scaffold_regression/743c9e45-04e2-495c-a378-24f7e910a127', result_dir='/content', model_tarball_path='/content/delaney_curated_model_743c9e45-04e2-495c-a378-24f7e910a127.tar.gz', system='twintron-blue', config_file=None, num_model_tasks=1, dropout_list=None, hyperparam=False, hyperparam_uuid=None, layer_nums=None, lc_account='baasic', max_final_layer_size=32, max_jobs=80, node_nums=None, nn_size_scale_factor=1.0, python_path='/usr/bin/python3', rerun=True, script_dir='/usr/local/lib/python3.10/dist-packages/atomsci/ddm', search_type='grid', split_only=False, shortlist_key=None, use_shortlist=False, slurm_account=None, slurm_export='ALL', slurm_nodes=1, slurm_options=None, slurm_partition='pbatch', slurm_time_limit=1440, lr=None, ls=None, ls_ratio=None, dp=None, rfe=None, rfd=None, rff=None, xgbg=None, xgbl=None, hp_checkpoint_save=None, hp_checkpoint_load=None, AttentiveFPModel_num_timesteps=None, AttentiveFPModel_num_layers=None, AttentiveFPModel_number_bond_features=None, AttentiveFPModel_model=None, AttentiveFPModel_wandb=None, AttentiveFPModel_loss=None, AttentiveFPModel_tensorboard=None, AttentiveFPModel_n_classes=None, AttentiveFPModel_dropout=None, AttentiveFPModel_wandb_logger=None, AttentiveFPModel_batch_size=None, AttentiveFPModel_device=None, AttentiveFPModel_graph_feat_size=None, AttentiveFPModel_output_types=None, AttentiveFPModel_optimizer=None, AttentiveFPModel_regularization_loss=None, Atten ...

# %%
# !date
# Out:
# Mon Feb 19 02:35:36 AM UTC 2024
